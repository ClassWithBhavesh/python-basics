# %% [markdown]
# # ***Conditional Statements in Python***
#
# whenever we have to operate something on the basis of some condtions (jab bhi hume kisi condition ke basis pr koi execution ya operation karwana ho to hum conditional statements use karte hai!)
#
#
#
# *   if
# *   else
# *   elif

# %%
# condition statement - if day is sunday then print 'day is sunday!'
# here we have only one condition, therefore we will use 'if' only

# day = 'sunday'
# if day == 'sunday':
#   print("day is sunday!")



# condition statement - if day is sunday then print 'day is sunday' else print 'day is Monday'
# agar day ki value sunday hai to print karo 'day is sunday' nahi to print karo 'day is monday'
# day = 'wednesday'
# if day == 'wednesday':
#   print('day is wednesday!')
# else:
#   print('day is monday!')



# condition statement - if day is monday then print 'today is monday'
# if day is tuesday then print 'today is tuesday'
# if day is wednesday then print 'today is wednesday'
# if day is thursday then print 'today is thursday'
# if day is Friday then print 'today is Friday'
# if day is Saturday then print 'today is Saturday'
# if day is Sunday then print 'today is Sunday'
# day = 'february'
# if day == 'monday':
#   print('today is monday')
# elif day == 'tuesday':
#   print('today is tuesday')
# elif day == 'wednesday':
#   print('today is wednesday')
# elif day == 'thursday':
#   print('today is thursday')
# elif day == 'friday':
#   print('today is friday')
# elif day == 'saturday':
#   print('today is saturday')
# elif day == 'sunday':
#   print('today is sunday')
# else:
#   print('value is not a week day, please provide week day!')
# Out:
# value is not a week day, please provide week day!
