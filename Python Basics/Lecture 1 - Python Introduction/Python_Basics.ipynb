# %% [markdown]
# # ***Fundamental Of Python***
#
# 1.   Programming Language
# 2.   Compiler & Interpretor
# 3.   Python Programming
# 4.   Fundamentals Concepts -
#       *   Variables in Python
#           * What is Variables
#           * How to declare a variables
#           * Criteria (Rules) of Declaring Variable
#       *   Data-Types in Python
#           * Integers
#           * Strings
#           * Float
#           * Boolean
#       *   Operators in Python
#           * Arithmatic Operators
#           * Assignments Operators
#           * Comparison Operators
#           * Logical Operators
#           * Bitwise Operators
#           * Membership Operators
#           * Identity Operators
#       * Conditional Statments in Python
#           * If | Else | Elif statements
#       * Control-Flow Statements
#           * while loops
#           * for loops
#       * Functions in Python
#           * Pre-Built Functions
#           * User-Defined Functions
#           * Anonymous Function
#           * Lambda Function
#       * Exception(Error) Handling

# %%
# Basic syntax of python to print something
# print("Hello Vikas")

# %% [markdown]
# # ***Variables in Python***

# %%
# Variables - it is nothing but a simple name given to store data or value\
# we can say for our understanding that a variable is like a container that holds or stores some data
# the variable must be a meaningful name

# chess_score = 18
# userName = "Vikash"

# 1userName = "Vikash"
# username2 = "Bhavesh"

# userName = "Vikash"
# username = "Bhavesh"
# print(userName)
# print(username)

# chocolatecount # lowercase
# CHOCOLATECOUNT # UPPERCASE
# chocolateCountOfBelgiumChocolate # camelCase
# ChocolateCountOfBelgiumChocolate # PascalCase
# chocoCount
# ChocoCount
# chococount
# ChocoCount
# choco1Count
# choco2Count
# chocoCount1
# chocoCount2
# chocoCount_1
# chocoCount_2
# Out:
# Vikash
# Vikash
# Vikash
# Vikash
# Vikash
# Bhavesh

# %% [markdown]
# # ***Data-Types in Python***
#
# Data-Type is a Type of Data
#
# types of data-type
# 1. Integer
# 2. Float
# 3. String
# 4. Boolean

# %%
# string - str - group of characters
# greenBottle = "Water"
# greenBottle = 'Water'
# print(greenBottle)
# type(greenBottle)


# Integer - int --> -inf to +inf, can't include decimal values
# roti_count = 12
# print(roti_count)
# type(roti_count)


# Float - float --> -inf to +inf, incudes decimal values
# vikash_weight = 52.56
# print("Vikash weightage", vikash_weight , "KG")     # concatenation - merge karna kinko?   do alag entity  # kon - keti - nation
# type(vikash_weight)


# Boolean - bool --> True & False
# day = True
# day = False
# print(day)
# type(day)
# Out:
# False
# bool
