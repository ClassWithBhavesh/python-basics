# %% [markdown]
# # ***Logical Operators in Python***
#
# is used to perform logics between two comparison operators. that means if you're comparing something and you've 2 or more than 2 conditions than between those two or more condition you'll gonna use ***Logical Operators***
#
# 1.   and (AND)
# 2.   or (OR)
# 3.   not (NOT)

# %%
base = 12.5
perpendicular = 12
hypotenius = 13

# base < perpendicular
# base < hypotenius

# hypotenius > base
# hypotenius > perpendicular

# perndicular > base
# perpendicular < hypotenius

# isTriangle = True   --->   Right Angle Triangle
# isTriangle = False   --->  Not Right Angle Triangle

# isTriangle = base < perpendicular
# print(isTriangle)
# isTriangle = base < hypotenius
# print(isTriangle)

# in this scenario we'll use Logical Ops because here we have more than one condition
# and to identify whether the given parameter are of Right Angel Triangle or not we will use "and" operator

# isTriangle = base < perpendicular and base < hypotenius
# isTriangle



num1 = 11
num2 = 5
num3 = 6

# and - strict condition
# or  - casual condition
# not - work just opposite with respect to 'and' & 'or'
        # if 'and' return True than 'not' will replicate this value to False and vice-versa
        # if 'or' return True than 'not' will replicate this value to False and vice-versa

# # fString- through this you can concat the string as well as the outcome or variable together

# if(num1 > num2 and not(num1 > num3)):
#   print(f"num1 is greater among all the numbers")
# elif(not(num2 > num3 and num2 > num1)):
#   print(f"num2 is greater among all the numbers")
# elif(num3 > num1 and num3 > num2):
#   print(f"num3 is greater among all the numbers")
# else:
#   print("All numbers are equal")
# Out:
# num2 is greater among all the numbers

# %% [markdown]
# # ***Practice Questions***

# %%
# 1. Predict the output:

# x = 10
# y = 20
# if x + y > 25:
#     print("A")
# else:
#     print("B")

# 2. What will be printed and why?

# a = 5
# b = 10
# if a * 2 == b:
#     print("Equal")
# else:
#     print("Not Equal")

# 3. Find the output:

# x = 15
# if x % 2 == 0:
#     print("Even")
# elif x % 3 == 0:
#     print("Divisible by 3")
# else:
#     print("None")

# 4. What happens here?

# x = 10
# y = 5
# if x > y and y > 0:
#     print("Valid")
# else:
#     print("Invalid")

# 5. Predict the output:

# a = 10
# b = 20
# c = 30
# if a < b < c:
#     print("Ascending")
# else:
#     print("Not Ascending")

# 6. What is printed?

# x = 5
# x += 3
# if x == 8:
#     print("Correct")

# 7. Output?

# x = 10
# if not x > 15:
#     print("Inside")
# else:
#     print("Outside")

# 8. What will be printed?

# a = 0
# if a:
#     print("True")
# else:
#     print("False")

# 9. Predict the result:

# x = 20
# if x >= 10 and x <= 30:
#     print("Range")
# else:
#     print("Out of Range")

# 10. Output?

# x = 5
# y = 10
# if x > y or y > x:
#     print("One Condition True")

# 11. What happens?

# a = 10
# b = 5
# if a == b:
#     print("Equal")
# elif a > b:
#     print("Greater")
# else:
#     print("Smaller")

# 12. Predict the output:

# x = 10
# y = 3
# if x // y == 3:
#     print("Yes")
# else:
#     print("No")

# 13. What is printed?

# x = 7
# if x % 2 != 0 and x % 3 != 0:
#     print("Special")
# else:
#     print("Normal")

# 14. Output?

# a = 5
# b = 2
# if a ** b > 20:
#     print("Power")
# else:
#     print("Low")

# 15. What happens?

# x = 10
# y = 20
# x = y
# if x == 20:
#     print("Assigned")

# 16. Predict the output:

# x = 15
# if x < 10:
#     print("Low")
# elif x < 20:
#     print("Medium")
# else:
#     print("High")

# 17. What will be printed?

# a = 10
# if a > 5 and not a > 20:
#     print("Accepted")

# 18. Output?

# x = 0
# if x == False:
#     print("Zero")

# 19. Predict the output:

# x = 25
# if x % 5 == 0 and x % 10 == 0:
#     print("Divisible")
# else:
#     print("Not Fully Divisible")

# 20. What happens?

# a = 10
# b = 10
# if a is b:
#     print("Same")
# else:
#     print("Different")



# SECTION B: REAL-LIFE SCENARIO QUESTIONS (20)

# 21. A shop gives a discount if bill amount is greater than ₹1000.
# Write logic to print “Discount Applied” or “No Discount”.

# 22. A student passes if marks ≥ 40.
# Print Pass or Fail.

# 23. A user can log in only if:

# Username is correct AND

# Password is correct
# Write conditional logic.

# 24. An employee gets a bonus if experience ≥ 5 years and salary < ₹50,000.
# Print eligibility.

# 25. A temperature is considered Hot if above 35°C, Normal if between 20–35, else Cold.

# 26. A number is considered valid if it is positive and even.

# 27. A movie ticket price depends on age:

# Age < 12 → Child

# Age 12–59 → Adult

# Age ≥ 60 → Senior

# 28. A bank allows withdrawal only if balance ≥ withdrawal amount.

# 29. A number is a multiple of both 3 and 5.
# Print result.

# 30. A delivery is Free if order value ≥ ₹500 OR user is a premium member.

# 31. A password is accepted only if its length ≥ 8.

# 32. A student is eligible for exam if attendance ≥ 75%.

# 33. A device is considered Low Battery if charge ≤ 20%.

# 34. A number is special if divisible by 4 but not by 8.

# 35. An employee rating:

# ≥ 90 → Excellent

# ≥ 70 → Good

# Else → Needs Improvement

# 36. A loan is approved if credit score ≥ 750.

# 37. A speed violation occurs if speed > 60 km/hr.

# 38. A product is taxable if price > ₹1000.

# 39. An online exam allows submission only if time remaining > 0.

# 40. A person is eligible to vote if age ≥ 18.
