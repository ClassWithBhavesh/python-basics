# %% [markdown]
# # ***Recursion in Python***
#
# - Recursion is a function which will call it self with in the same function.
# - It will ease the process of looping through repeatedly calling it self
# - Recursive function will executes infinite if no base case is passed.

# %%
# iter = -1
# def iter1To100(n):
#   if n < 0:
#     print("can't iterate the negative values!")
#   else:
#     if n < 100:
#       print(n)
#       n+=5
#       iter1To100(n)
#     else:
#       print(n)

# iter1To100(iter)

# for num in range(1, 101):
#   print(num)
# Out:
# can't iterate the negative values!

# %%
# factorial formula - n * (n-1) * (n-2) * (n-3) * (n-4) * ...... * n

# def iden_factorial(n):
#   if n <= 0:
#     print("factorial can't be found for 0 value")
#   factorial = 1
#   for num in range(2, n + 1):
#     factorial *= num
#   return factorial

# factorialIs = iden_factorial(5)
# factorialIs


# interview question - find the factorial for the given nth term by the user

def fact(num):
  if num == 1:
    return num
  else:
    return num * fact(num - 1)   #  5 x 4 x 3 x 2 x 1

givenNumber = int(input("Enter any number - "))
factForGivenNumber =  fact(givenNumber)
print(f"factorial for the {givenNumber} is - {factForGivenNumber}")
# Out:
# Enter any number - 7
# factorial for the 7 is - 5040
