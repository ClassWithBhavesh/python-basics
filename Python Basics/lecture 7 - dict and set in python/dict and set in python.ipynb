# %% [markdown]
# # ***Memebership Operators in Python***
#
# is used to check whether an element is present in a dataset or not, which means that this operator will return a boolean value by checking that a value is present in a dataset or not
#
# 1.   in
# 2.   not in

# %%
# before practicing memebership and identity operator we must know all Data-Types
# Data-types - type of data which is stored in a variable
# types of data-types -
    #  1. primitive data types - int, float, str, bool, null, complex number
    #  2. non-primitive data types - list, tuple, set, dictionary (dict)

# %% [markdown]
# # ***List in Python***
#
# *   it is a well defined collection of elements of similar data-types or different data-types
# *   it is denoted by '[value1, value2, value3, value4, ..., valueN]'
# *   Each and Every Element are separated by commas ','
# *   it is mutable data structure (we can change or update the data or values in the list.)
# *   it will store data in sequential (Structured manner), that's why it is a well defined (means well structured)
# *   Each and Every Elements have their unique identity known as "Index" or "Indices"
# *   Index Values always starts from 0 and goes up to (length of list - 1)

# %%
# li = []    # empty list
# li
# type(li)

# li = [10,20,30,50,20,60]
# li

# strLi = ["Vikas", "Rahul", "Himanshu", "Vinay", "Rajesh"]
# strLi

# rahulData = ["Rahul Mishra", 457885412556, 29, 'male', '21-05-2001',1020,50,10,20,60]
# len(rahulData)

# indexing - is a process in which we will target specific values from a list | tuple | dict
# syntax to perform indexing - listName[indexValue]

# print(rahulData[3])

# print(rahulData[0])

# print(rahulData[9])
# Out:
# male
# Rahul Mishra
# 60

# %% [markdown]
# # ***Tuple in Python***
#
#
#
# *   is a well defined collection of similar data-types elements as well as different data-types elements
# *   Now, you'll think that the list and tuples are same. it's not, tuple is slightly different from List
# *   List is Mutable (can be change or update anytime), but tuple is immutable (can't be update or changed after declared)
# *   it is denoted by '()' parenthetsis
# *   each and every element are separated by ',' comma
# *   this is a structured (Ordered) non-primitive data-type / structure
# *   every element of tuple has a unique identity known as index value or indices
# *   index value starts from 0 to (length of tuple - 1)

# %%
# tuple = 1452
# print(tuple) # here if you'll declare a variable using keywords which are pre-defined in python than the variable would be declared but,
             # it can cause little confusions if you're going to use that pre-defined keyword again and again
# Out:
# 1452

# %%
# tup = () # Empty Tuple - bole to bilkul khaaliii

# print(tup)
# type(tup)


# tup = (1,2,3,4,5,6,7,8,9)    # declaration of tuple
# print(tup)
# # tup

# tup = ("Rahul", "Bijay", "Harsh", "Shantilal")   # Re-Decalaration of tuple
# print(tup)



li = [10,20,30,40]
li[3]

li.append(45)
li

li.insert(3, 55)
li
# # updating list using indexing -
# print(f"before updation - {li}")
# print(li[2])
# li[2] = 96    # updating li value (2nd index)
# print(f"after updation - {li}")
# print(li[2])  # indexing of list


# print(li)
# indexing in list
# print(li[2])
# print(li[0])



# tup = (10,20,30,40)
# updation in tuple (updating tuple)
# print(f"before updation tup is - {tup}")
# tup[1] = 96
# print(f"after updation tup is - {tup}")

# tup[4] = 45

# print(tup)
# indexing in tuple
# print(tup[2])
# print(tup[4])
# Out:
# [10, 20, 30, 55, 40, 45]

# %% [markdown]
# # ***Dictionary in Python***
#
# *   it is a well defined collection of elements of similar data-type or different data-type but in the key-value pair
# *   Each Key carries a value
# *   denoted by '{}'
# *   each and every element are separated by comma
# *   structured data structure (ordered)
# *   No index values like tuple and list, but having a unique value known as 'key' and we can perform indexing using 'key'
# *   that means every key in the dictionary must be unique
# *   if you'll use the same key again and again than the updated value must be considered
# *   dictionaries are mutable data type

# %%
empDict = {}    # empty dictionary
# print(empDict)
# type(empDict)


employeeData1 = {
    "empName": ("Rahul", "Vikas", "Arjun", "Balram"),
    "empAge1": [38, 24, 29, 23],
    "empSalary": [50000, 24600, 12000, 39000],
    "empAge": (18, 28, 25, 21)        # don't use same key, let the key unique everywhere
}
# print(employeeData)


# updating employeeData1 -
# employeeData1['empName'][2] = "Karan"


employeeData2 = {
    'empBoss': "Selmon Bhai",
    "empName": ["Rahul", "Vikas", "Arjun", "Balram"],
    "empAge1": [38, 24, 29, 23],
    "empSalary": [50000, 24600, 12000, 39000],
    "empAge": [38, 24, 29, 23]        # don't use same key, let the key unique everywhere
}
print(employeeData)

# employeeData2['empName'][2] = "Karan"
# employeeData2['empName']

# employeeData2["empBoss"]


# targeting specific element using 'key' in dictionary
# employeeData['empAge1']
# Out:
# {'empName': ('Rahul', 'Vikas', 'Arjun', 'Balram'), 'empAge1': [38, 24, 29, 23], 'empSalary': [50000, 24600, 12000, 39000], 'empAge': (18, 28, 25, 21)}

# %% [markdown]
# # ***Set in Python***
#
#
# *   it is a collection (not a well defined collection) of similar data-type element or different data-type elements but their a twist
# *   unlike list and tuple, set doesn't have index values because it is unordered (not well defined)
# *   their is no index value
# *   unordered
# *   always consider unique values (can't store duplicates)

# %%
# set1 = {}           # empty dictionary
# print(set1)
# type(set1)


# empSet = set({})    # empty set
# print(empSet)
# type(empSet)


set1 = {9,1,10,2,3,78,4,5,6,78, 4,9,10}
print(set1)
# set1[0]    # can't perform indexing on set
# type(set1)
# Out:
# {1, 2, 3, 4, 5, 6, 9, 10, 78}
