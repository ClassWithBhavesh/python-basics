# %% [markdown]
# # ***Functions in Python***
#
# are bunch of codes (containers containing python codes) which will performing certain task or process or operation efficiently.
#
# Function are reusable for the same as well as different arguments

# %%
# num1 = 21
# num2 = 86
# result = num1 + num2
# print(result)


# num1 = 21
# num2 = 86
# result = num1 + num2
# print(result)


# num1 = 21
# num2 = 86
# result = num1 + num2
# print(result)


# num1 = 21
# num2 = 86
# result = num1 + num2
# print(result)


# num1 = 21
# num2 = 86
# result = num1 + num2
# print(result)


# num1 = 21
# num2 = 86
# result = num1 + num2
# print(result)


# to declare a function - syntax to use a function
# def funcName():
  # function body (jo bhi operation perform karna hai uska code)

# funcName()

# steps to execute a function - 1. Declaring a function     2. Calling a function

# Types of function -
# 1. Standard function -
# def sum():
#   num1 = 21
#   num2 = 86
#   result = num1 + num2
#   print(result)

# sum();
# sum();
# sum();
# sum();
# sum();
# sum();



# 2. Parametric functions -
# def sum(num1, num2, num3, num4, num5):
#   result = num1 + num2 + num3 + num4 + num5
#   print(result)

# def sum(num1, num2):
#   result = num1 + num2
#   print(result)

# sum(25, 87);
# sum(21, 46);
# sum(-25, 0);
# sum(19, -71);
# sum(-58, 39);
# sum(.0012, 8.96);



# 3. function with return value -
# kisi din kisi situation me aapko function use to karna hai, uska operation to perform karna hai lekin jo resultant value hai usse execute nahi karna hai.
# esi situation me aap usse return kar sakte ho! kya hoga return karne se?
# return karne se jo bhi resultant value hai wo store ho jayegi (return gho jayegi) kiske andar? --> function ke andar jisme wo resultant value operate ki gayi ho

# prepare a full fledged result of 10th standard student whose name is "Kartik"
# mathsMarks = int(input("enter Maths marks -"))
# scMarks = int(input("enter Science marks -"))
# hnMarks = int(input("enter Hindi marks -"))
# engMarks = int(input("enter English marks -"))
# sstMarks = int(input("enter SST marks -"))
# totalMarks = int(input("Enter Total Marks - "))

# def obtMarks(mathsMarks, scMarks, hnMarks, engMarks, sstMarks):
#   obt_marks = mathsMarks + scMarks + hnMarks + engMarks + sstMarks
#   return obt_marks


# def percentage(ob_marks, t_marks):
#   per = (ob_marks/t_marks) * 100
#   return per

# def gradingSystem(std_ob_marks, std_per, t_marks):
#   if std_per > 90 and std_per <= 100:
#     print(f"Kartik scored {std_ob_marks} out of {t_marks} and got {std_per}% and secured 'A' grade")
#   elif std_per > 80 and std_per <= 90:
#     print(f"Kartik scored {std_ob_marks} out of {t_marks} and got {std_per}% and secured 'B' grade")
#   elif std_per > 70 and std_per <= 80:
#     print(f"Kartik scored {std_ob_marks} out of {t_marks} and got {std_per}% and secured 'C' grade")
#   elif std_per > 60 and std_per <= 70:
#     print(f"Kartik scored {std_ob_marks} out of {t_marks} and got {std_per}% and secured 'D' grade")
#   elif std_per > 33 and std_per <= 60:
#     print(f"Kartik scored {std_ob_marks} out of {t_marks} and got {std_per}% and secured 'E' grade")
#   else:
#     print("Kartik got failed, better luck for the next time")



# ob_marks = obtMarks(mathsMarks, scMarks, hnMarks, engMarks, sstMarks)
# std_percentage = percentage(ob_marks, totalMarks)
# gradingSystem(ob_marks, std_percentage, totalMarks)

# %%
num1 = float(input("Enter Value For Num1 - "))
num2 = float(input("Enter Value For Num2 - "))

print(f"Chosse any one operator - +  |  -  |  *  |  /  |  //  |  **  |  %")
op = input("Enter any operator : ")

if op == "+":
  print(f"the addition of {num1} and {num2} is {num1 + num2}")
elif op == "-":
  print(f"the subtraction of {num1} and {num2} is {num1 - num2}")
elif op == "*":
  print(f"the product of {num1} and {num2} is {num1 * num2}")
elif op == "/":
  if num2 != 0:
    print(f"the division of {num1} and {num2} is {num1 / num2}")
  else:
    print(f"you tried dividing {num1} with 0, which is undefined")
    print(f"unable to perform division because anything divided by 0 is undefined")
elif op == "%":
  if num2 != 0:
    print(f"the modulus(remainder) of {num1} / {num2} is {num1 % num2}")
  else:
    print(f"you tried dividing {num1} with 0, which is undefined")
    print(f"unable to perform division because anything divided by 0 is undefined")
elif op == "//":
  if num2 != 0:
    print(f"the floor-division of {num1} and {num2} is {num1 // num2}")
  else:
    print(f"you tried dividing {num1} with 0, which is undefined")
    print(f"unable to perform division because anything divided by 0 is undefined")
elif op == "**":
  print(f"the result of {num1} to the power {num2} is {num1 ** num2}")
else:
  print(f"{op} is not a valid operator, please choose valid operator!")
# Out:
# Enter Value For Num1 - 20
# Enter Value For Num2 - 25
# Chosse any one operator - +  |  -  |  *  |  /  |  //  |  **  |  %
# Enter any operator : 25 + 26- 63/ 99 * 10 / 50 ** 2 // 10 % 5
# 25 + 26- 63/ 99 * 10 / 50 ** 2 // 10 % 5 is not a valid operator, please choose valid operator!

# %%
# 7.
userInput = input("Enter a Alpha Character - ")

def checkVowel(A_char):
  if A_char == "a" or A_char == "e" or A_char == "i" or A_char == "o" or A_char == "u":
    return f"{A_char} is a Vowel"
  else:
    return f"{A_char} is a Consonant"

checkOutput = checkVowel(userInput)
checkOutput
# Out:
# Enter a Alpha Character - i
# 'i is a Vowel'

# %%
# 5.
# userNum1 = int(input("Enter any number - "))  # 74589      ---> 33
# userNum2 = int(input("Enter any number - "))  # 145789     ---> 34
# userNum3 = int(input("Enter any number - "))  # 652        ---> 13
# userNum4 = int(input("Enter any number - "))  # 5552226353 ---> 38

# def sumOfNum(n):
#   temp = n
#   sum = 0

#   while temp > 0:
#     spNum = temp%10
#     sum += spNum
#     temp //= 10     # temp = temp // 10

#   print(f"the sum of all digits of {n} is - {sum}")

# sumOfNum(userNum1)
# sumOfNum(userNum2)
# sumOfNum(userNum3)
# sumOfNum(userNum4)
# Out:
# Enter any number - 74589
# Enter any number - 145789
# Enter any number - 652
# Enter any number - 5552226353
# the sum of all digits of 74589 is - 33
# the sum of all digits of 145789 is - 34
# the sum of all digits of 652 is - 13
# the sum of all digits of 5552226353 is - 38
