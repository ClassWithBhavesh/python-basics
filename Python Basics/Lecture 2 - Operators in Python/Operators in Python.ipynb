# %% [markdown]
# # ***Operators in Python***
#
# **operator** - is a symbol which is used to perform operations on two or more operands
#
# **operands** - are values on which we will perform operations using operators
#
# **operations** - is a process where we perform something on two or more operands using operators

# %%
# 1. Arithmatic operators -
# + (addition), - (Subtraction), * (astrick), / (Division), ** (exponential), // (floor division), % (modulus)

# %%
# Addition - (+)
# EcoMarks1 = 45
# EcoMarks2 = 79

# # print(EcoMarks1 + EcoMarks2)       # to print the result directly we use print() method

# result = EcoMarks1 + EcoMarks2     # to store the resultant value for future reference
# print("Vikash Scores", result, "marks in Economics")



# Subtraction - (-)
# EcoMarks1 = 45
# EcoMarks2 = 79

# # print(EcoMarks1 + EcoMarks2)       # to print the result directly we use print() method

# result = EcoMarks1 + EcoMarks2     # to store the resultant value for future reference
# finalResult = result - 10
# print("Vikash Scores", finalResult, "marks in Economics")



# Subtraction - (*)
# num1 = 2
# num2 = 9

# result = num1 * num2    # to store the resultant value for future reference
# print("multiplication of num1 and num2 is", result)



# Division - (/)
# num1 = 54
# num2 = 4

# result = num1 / num2    # to store the resultant value for future reference
# print("Division of num1 and num2 is", result)



# Exponential - (**)
# num1, num2 = 2, 6
# # answer = num1**num2
# answer = num2**num1
# print(answer)



# floor division - (//)
# num1 = 54
# num2 = 4

# result = num1 // num2  # always returns an integer value even the answer is in decimal(float)
# print(result)




# Modulus - (%)
# num1 = 2
# num2 = 10

# result = num1 % num2  # always returns remainder(integer value)
# print(result)

# %%
# 2 Assignment Operator - +=, -=, *=, /=, //=, %=, **=, =

# +=
# num1 = 15
# num2 = 64
# print(num1 + num2)

# num1 = -15
# num2 = 64
# print("num1 is - ", num1)
# print("num2 is - ", num2)

# num1 = num1 + num2
# print("num1 is - ", num1)

# num2 = num2 + num1
# print("num2 is - ", num2)


# num1 += num2    # num1 = num1 + num2
# num2 += num1    # num2 = num2 + num1

# print(num1)
# print(num2)



# -=
# num1 = -55
# num2 = 49

# num1 -= num2     # num1 = num1 - num2
# num2 -=  num1    # num2 = num2 - num1

# print(num1, num2)



# # *=
# num1 = -5
# num2 = 4

# num1 *= num2     # num1 = num1 * num2
# num2 *=  num1    # num2 = num2 * num1

# print(num1, num2)



# /=
# num1 = -5
# num2 = 4

# num1 /= num2     # num1 = num1 / num2
# num2 /=  num1    # num2 = num2 / num1

# print(num1, num2)



# //=
# num1 = -75
# num2 = 10

# num1 //= num2     # num1 = num1 // num2
# num2 //=  num1    # num2 = num2 // num1

# print(num1, num2)



# %=
# num1 = 75
# num2 = 10

# num1 %= num2     # num1 = num1 % num2
# num2 %=  num1    # num2 = num2 % num1

# print(num1, num2)


# **=
# num1 = 4
# num2 = 3

# num1 **= num2     # num1 = num1 ** num2
# num2 **=  num1    # num2 = num2 ** num1

# print(num1, num2)
# Out:
# 5 0
