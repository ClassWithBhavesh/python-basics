# %% [markdown]
# # ***Column Operations in Pandas***

# %% [markdown]
# ### **Targeting single or more than one column in Pandas**

# %%
import pandas as pd

df = pd.read_csv("product_data.csv")
print(df)
# print(type(df))
sizeCol = df['color']
# sizeCol
# print(type(sizeCol))

# costPrice = df['cost_price']
# costPrice

# prodInfo = df[['category', 'size', 'list_price']]
# prodInfo
# Out:
#       product_id     category   color size  season   supplier  cost_price  \
# 0        P000001      Bottoms   Black   XL  Spring  supplierb       78.26
# 1        P000002          ???   Black    M  Summer  supplierc       39.67
# 2        P000003         Tops   Black   XL  Summer  supplierd       27.62
# 3        P000004  Accessories   White   XL  Winter  supplierb        7.43
# 4        P000005  Accessories     NaN   XL    Fall  suppliera       12.04
# ...          ...          ...     ...  ...     ...        ...         ...
# 49995    P049996      Bottoms  Yellow   XS  Winter  supplierc        6.86
# 49996    P049997  Accessories   White    S    Fall  supplierb       30.51
# 49997    P049998      Dresses   White    L  Spring  suppliera       70.61
# 49998    P049999         Tops     Red    L  Winter  suppliera       72.73
# 49999    P050000      Dresses    Blue   XL  Spring  supplierb       25.73
#
#        list_price
# 0           46.45
# 1          147.82
# 2           44.40
# ...

# %% [markdown]
# ### **Adding and Inserting new columns in pandas DataFrames**

# %%
# adding new column at the end of the DataFrame
df['discount_price'] = df['cost_price'] * 10 / 100

# %%
# inserting new column at our desired location in the DataFrame using insert method
# df.insert(posi, columnName, columnValue)

df.insert(6, 'final_price', df['cost_price'] - df['discount_price'])

# %%
df
# Out:
#       product_id     category   color size  season   supplier  final_price  \
# 0        P000001      Bottoms   Black   XL  Spring  supplierb       70.434
# 1        P000002          ???   Black    M  Summer  supplierc       35.703
# 2        P000003         Tops   Black   XL  Summer  supplierd       24.858
# 3        P000004  Accessories   White   XL  Winter  supplierb        6.687
# 4        P000005  Accessories     NaN   XL    Fall  suppliera       10.836
# ...          ...          ...     ...  ...     ...        ...          ...
# 49995    P049996      Bottoms  Yellow   XS  Winter  supplierc        6.174
# 49996    P049997  Accessories   White    S    Fall  supplierb       27.459
# 49997    P049998      Dresses   White    L  Spring  suppliera       63.549
# 49998    P049999         Tops     Red    L  Winter  suppliera       65.457
# 49999    P050000      Dresses    Blue   XL  Spring  supplierb       23.157
#
#        cost_price  list_price  discount_price
# ...

# %%
# loc method -
# df.loc[499, 'category']
# df.loc[499, 'season']
# df.loc[499]

# iloc method -
# df.iloc[499, 4]
# Out:
# product_id          P000500
# category            Dresses
# color                 White
# size                      M
# season               Summer
# supplier          supplierd
# final_price           5.202
# cost_price             5.78
# list_price           113.94
# discount_price        0.578
# Name: 499, dtype: object
